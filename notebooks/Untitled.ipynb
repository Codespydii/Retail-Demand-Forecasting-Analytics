# %%
pip install streamlit
# Out:
# ...
#
# ...

# %%
pip install joblib pandas shap matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
app.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 app.py
#
# NameError: name 'app' is not defined
