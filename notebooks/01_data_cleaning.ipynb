# %% [markdown]
# Retail Demand Forecasting
#
# Phase 3 - Data Cleaning
#
# Business Objective
# Prepare a clean and reliable dataset for exploratory analysis and machine learning by handling missing values, correcting data types, identifying outliers, and ensuring data quality.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

plt.style.use("ggplot")

# %%
df = pd.read_csv(r"C:\Users\mahip\Desktop\Retail-Demand-Forecasting-Analytics\data\processed\merged_data.csv")
# Out:
# C:\Users\mahip\AppData\Local\Temp\ipykernel_5432\2145399501.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\mahip\Desktop\Retail-Demand-Forecasting-Analytics\data\processed\merged_data.csv")

# %%
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
df.shape
# Out:
# (1017209, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  object
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth  693861 non-null   float64
# ...

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing
# Out:
# Promo2SinceWeek              508031
# PromoInterval                508031
# Promo2SinceYear              508031
# CompetitionOpenSinceYear     323348
# CompetitionOpenSinceMonth    323348
# CompetitionDistance            2642
# DayOfWeek                         0
# Store                             0
# Date                              0
# Sales                             0
# StoreType                         0
# SchoolHoliday                     0
# StateHoliday                      0
# Promo                             0
# Open                              0
# Customers                         0
# Assortment                        0
# Promo2                            0
# dtype: int64

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_df = pd.DataFrame({
    "Missing Values": missing,
    "Percentage": missing_percent
}).sort_values("Percentage", ascending=False)

missing_df
# Out:
#                            Missing Values  Percentage
# PromoInterval                      508031   49.943620
# Promo2SinceYear                    508031   49.943620
# Promo2SinceWeek                    508031   49.943620
# CompetitionOpenSinceMonth          323348   31.787764
# CompetitionOpenSinceYear           323348   31.787764
# CompetitionDistance                  2642    0.259730
# Assortment                              0    0.000000
# DayOfWeek                               0    0.000000
# Customers                               0    0.000000
# Date                                    0    0.000000
# Promo2                                  0    0.000000
# Promo                                   0    0.000000
# Open                                    0    0.000000
# Sales                                   0    0.000000
# SchoolHoliday                           0    0.000000
# StateHoliday                            0    0.000000
# ...

# %%
plt.figure(figsize=(10,6))

sns.heatmap(df.isnull(), cbar=False)

plt.title("Missing Values Heatmap")

plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df["Date"].dtype
# Out:
# dtype('O')

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# Store                                 int64
# DayOfWeek                             int64
# Date                         datetime64[ns]
# Sales                                 int64
# Customers                             int64
# Open                                  int64
# Promo                                 int64
# StateHoliday                         object
# SchoolHoliday                         int64
# StoreType                            object
# Assortment                           object
# CompetitionDistance                 float64
# CompetitionOpenSinceMonth           float64
# CompetitionOpenSinceYear            float64
# Promo2                                int64
# Promo2SinceWeek                     float64
# Promo2SinceYear                     float64
# PromoInterval                        object
# dtype: object

# %%
numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns

numerical_cols
# Out:
# Index(['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
#        'SchoolHoliday', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear'],
#       dtype='object')

# %%
categorical_cols = df.select_dtypes(include="object").columns

categorical_cols
# Out:
# Index(['StateHoliday', 'StoreType', 'Assortment', 'PromoInterval'], dtype='object')

# %%
df.describe().T
# Out:
#                                count                           mean  \
# Store                      1017209.0                     558.429727
# DayOfWeek                  1017209.0                       3.998341
# Date                         1017209  2014-04-11 01:30:42.846061824
# Sales                      1017209.0                    5773.818972
# Customers                  1017209.0                     633.145946
# Open                       1017209.0                       0.830107
# Promo                      1017209.0                       0.381515
# SchoolHoliday              1017209.0                       0.178647
# CompetitionDistance        1014567.0                    5430.085652
# CompetitionOpenSinceMonth   693861.0                       7.222866
# CompetitionOpenSinceYear    693861.0                    2008.690228
# Promo2                     1017209.0                       0.500564
# Promo2SinceWeek             509178.0                      23.269093
# ...

# %%
df.describe(include="object").T
# Out:
#                  count unique              top    freq
# StateHoliday   1017209      5                0  592943
# StoreType      1017209      4                a  551627
# Assortment     1017209      3                a  537445
# PromoInterval   509178      3  Jan,Apr,Jul,Oct  293122

# %% [markdown]
# Handling Missing values

# %%
df["CompetitionDistance"].fillna(
    df["CompetitionDistance"].median(),
    inplace=True
)
# Out:
# C:\Users\mahip\AppData\Local\Temp\ipykernel_5432\3402359425.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["CompetitionDistance"].fillna(

# %%
df.isnull().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance               0
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# dtype: int64

# %%
df.fillna({
    "CompetitionOpenSinceMonth": 0,
    "CompetitionOpenSinceYear": 0,
    "Promo2SinceWeek": 0,
    "Promo2SinceYear": 0,
    "PromoInterval": "None"
}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Store                        0
# DayOfWeek                    0
# Date                         0
# Sales                        0
# Customers                    0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.boxplot(data=df["Sales"])

plt.title("Sales Distribution")

plt.show()

# %%
plt.figure(figsize=(12,6))

sns.boxplot(data=df["Customers"])

plt.title("Customers")

plt.show()

# %%
plt.figure(figsize=(12,6))

sns.boxplot(data=df["CompetitionDistance"])

plt.title("CompetitionDistance")

plt.show()

# %%
df["Sales"].describe()
# Out:
# count    1.017209e+06
# mean     5.773819e+03
# std      3.849926e+03
# min      0.000000e+00
# 25%      3.727000e+03
# 50%      5.744000e+03
# 75%      7.856000e+03
# max      4.155100e+04
# Name: Sales, dtype: float64

# %%
(df["Sales"] < 0).sum()
# Out:
# np.int64(0)

# %%
df["Open"].value_counts()
# Out:
# Open
# 1    844392
# 0    172817
# Name: count, dtype: int64

# %%
df[df["Open"] == 0][["Sales", "Customers"]].head()
# Out:
#       Sales  Customers
# 291       0          0
# 875       0          0
# 1406      0          0
# 1990      0          0
# 2521      0          0

# %%
df.to_csv(
    "../data/processed/cleaned_data.csv",
    index=False
)
